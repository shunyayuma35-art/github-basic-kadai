# %%
# 台形の各辺の長さ（cm）
top = 10     # 上辺
bottom = 20  # 下辺
height = 5   # 高さ

# 面積の計算（台形の面積 =（上辺＋下辺）× 高さ ÷ 2）
area = (top + bottom) * height / 2

# 結果の出力（数値＋文字列）
print(str(area) + "cm²")
# Out:
# 75.0cm²
