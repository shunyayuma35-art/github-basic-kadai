# %% [markdown]
# <a href="https://colab.research.google.com/github/shunyayuma35-art/github-basic-kadai/blob/main/2025_11_22_tesuto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %%
n=2+3
print(n)
# Out:
# 5

# %%
# 例１
# 底辺が３，高さが２の三角形の面積を求めましょう、

# %%
from re import M
#底辺の長さをl、三角形の高さにhとすると、
l=3
h=2

# 三角形の面積をsとすると。
s=l*h/2
print(s)
# Out:
# 3.0
