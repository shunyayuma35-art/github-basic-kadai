# %%
# Gitのユーザー情報を設定 (ご自身の情報に置き換えてください)
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "Your Name"

# git_challenge ディレクトリを作成し、移動
# !mkdir -p git_challenge
# %cd git_challenge

# Gitリポジリを初期化
# !git init

# デフォルトの master ブランチを main にリネーム
# !git branch -M main

# 何かファイルを追加して最初のコミットを作成（例: .gitignore）
# !echo "# Ignore common Colab files" > .gitignore
# !echo "__pycache__/" >> .gitignore

# hello_world.txt を作成
# !echo "こんにちは、世界！" > hello_world.txt
# !echo "Hello, world!" >> hello_world.txt

# !git add .
# !git commit -m "Initial commit: Add .gitignore and hello_world.txt"

# リモートリポジリを接続
# <ユーザー名> を実際のGitHubユーザー名に置き換えてください
# !git remote add origin https://github.com/<ユーザー名>/git_challenge.git

# 初回プッシュ（mainブランチを送信）
# !git push -u origin main
# Out:
# /content/git_challenge
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/git_challenge/.git/
# [main (root-commit) 450b6af] Initial commit: Add .gitignore and hello_world.txt
#  2 files changed, 4 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 hello_world.txt
# /bin/bash: line 1: ユーザー名: No such file or directory
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# ...

# %%
# 判定対象の数値を変数に代入
var = 15  # 例として15を代入

# if文で条件分岐
if var % 3 == 0 and var % 5 == 0:
    print("FizzBuzz")
elif var % 3 == 0:
    print("Fizz")
elif var % 5 == 0:
    print("Buzz")
else:
    print(var)
# Out:
# FizzBuzz
