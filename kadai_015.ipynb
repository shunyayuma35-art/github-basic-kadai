# %% [markdown]
# <a href="https://colab.research.google.com/github/shunyayuma35-art/github-basic-kadai/blob/main/kadai_015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
        print(f"名前: {self.name}")
        print(f"年齢: {self.age}")

# インスタンスを作成して変数に代入
person = Human("田中太郎", 25)

# メソッドを使って情報を出力
person.printinfo()
# 💡 解説ポイント
# __init__ メソッドで name と age を初期化してるよ。

# printinfo メソッドで、インスタンスの属性を出力！

# person という変数にインスタンスを代入して、ちゃんとメソッドを呼び出してるから、合格基準もバッチリ満たしてるね！

# このコードを .ipynb にして kadai_015 フォルダに保存して、GitHub にプッシュすれば提出準備OK！
# クラスって最初はちょっと硬いけど、使いこなせるとすっごく便利なんだよ〜！他にもクラスで遊んでみたい？🐬






# ページ内で編集します
# Out:
# 名前: 田中太郎
# 年齢: 25
