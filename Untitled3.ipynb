# %% [markdown]
# <a href="https://colab.research.google.com/github/shunyayuma35-art/github-basic-kadai/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd git_challenge
git remote add origin https://github.com/<ユーザー名>/git_challenge.git
git push -u origin main
# Out:
#   File "/tmp/ipython-input-3570357648.py", line 1
#     cd git_challenge
#        ^
# SyntaxError: invalid syntax

# %%
git branch pull_request
git checkout pull_request
# Out:
#   File "/tmp/ipython-input-3733347418.py", line 1
#     git branch pull_request
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# こんばんは、世界！

# %%
git add hello_world.txt
git commit -m "hello_world.txt を修正"
git push origin pull_request
# Out:
#   File "/tmp/ipython-input-3335344550.py", line 1
#     git add hello_world.txt
#         ^
# SyntaxError: invalid syntax

# %%
git checkout main
git pull origin main
git branch -d pull_request
# Out:
#   File "/tmp/ipython-input-3311777994.py", line 1
#     git checkout main
#         ^
# SyntaxError: invalid syntax
